# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('ads_data.csv')
data.head
# Out:
# <bound method NDFrame.head of     Advertising Cost (USD)  Sales Revenue (USD)
# 0                      784          5167.683485
# 1                      659          4736.040926
# 2                      729          4799.105662
# 3                      292          2307.039663
# 4                      935          5917.849078
# 5                      863          5753.385395
# 6                      807          5348.687786
# 7                      459          3390.113449
# 8                      109           841.300662
# 9                      823          5324.660476
# 10                     377          2713.570097
# 11                     854          5926.878257
# 12                     904          5857.388520
# 13                     699          4703.472963
# 14                     170          1812.548089
# 15                     572          4239.005826
# 16                     700          4813.288008
# 17                     496          3505.853018
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Advertising Cost (USD)'], data['Sales Revenue (USD)'], color='blue', label='Data Points')
plt.xlabel('TV Advertising Budget (in thousands)')
plt.ylabel('Sales (in thousands)') 
plt.title('TV Advertising Budget vs Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
X = data[['Advertising Cost (USD)']]
y = data['Sales Revenue (USD)']

# %%
mse = mean_squared_error(y, y_pred)
model = LinearRegression()
