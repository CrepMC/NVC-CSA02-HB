# %%
import pandas as pd

# %%
df = pd.read_csv('Billionaires.csv')
# Out:
#       Rank                      Name Net Worth   Age Country | Territory  \
# 0        1  Bernard Arnault & family    $211 B  74.0              France
# 1        2                 Elon Musk    $180 B  51.0       United States
# 2        3                Jeff Bezos    $114 B  59.0       United States
# 3        4             Larry Ellison    $107 B  78.0       United States
# 4        5            Warren Buffett    $106 B  92.0       United States
# ...    ...                       ...       ...   ...                 ...
# 2635  2540                   Yu Rong      $1 B  51.0               China
# 2636  2540    Richard Yuengling, Jr.      $1 B  80.0       United States
# 2637  2540             Zhang Gongyun      $1 B  60.0               China
# 2638  2540    Zhang Guiping & family      $1 B  71.0               China
# 2639  2540               Inigo Zobel      $1 B  66.0         Philippines
#
#                             Source               Industry
# ...

# %% [markdown]
# ### The function is to remove B and $ of net worth object

# %%
def clean_networth(nw):
    if isinstance(nw, str):
        return nw[1:-1]
    return nw

df['Net Worth'] = df['Net Worth'].apply(clean_networth)
df['Net Worth'] = pd.to_numeric(df['Net Worth'])
df.head()
# Out:
#    Rank                      Name  Net Worth   Age Country | Territory  \
# 0     1  Bernard Arnault & family      211.0  74.0              France
# 1     2                 Elon Musk      180.0  51.0       United States
# 2     3                Jeff Bezos      114.0  59.0       United States
# 3     4             Larry Ellison      107.0  78.0       United States
# 4     5            Warren Buffett      106.0  92.0       United States
#
#                Source               Industry
# 0                LVMH       Fashion & Retail
# 1       Tesla, SpaceX             Automotive
# 2              Amazon             Technology
# 3              Oracle             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
df[["Industry", "Net Worth"]].groupby(["Industry"]).sum().sort_values(by="Net Worth", ascending=False)
# Out:
#                             Net Worth
# Industry
# Technology                     1871.0
# Fashion & Retail               1698.8
# Finance & Investments          1605.1
# Manufacturing                  1025.9
# Food & Beverage                 957.2
# Diversified                     905.2
# Real Estate                     657.4
# Healthcare                      643.2
# Automotive                      525.3
# Energy                          453.5
# Metals & Mining                 446.8
# Media & Entertainment           427.5
# Logistics                       239.5
# Telecom                         203.5
# Service                         173.4
# Sports                          134.5
# Gambling & Casinos              120.5
# Construction & Engineering      118.5

# %%
# %pip install pycountry-convert

# %%
import pycountry_convert as pc

def get_continient(country_name):
    try:
        country_code = pc.country_name_to_country_alpha2(country_name)
        continient_code = pc.country_alpha2_to_continent_code(country_code)
        continient_name = pc.convert_continent_code_to_name(continient_code)
        return continient_name
    except:
        print("Error converting country name:", country_name)
        return "Unknown"

df["Continent"] = df["Country | Territory"].apply(get_continient)
# Out:
# Error converting country name: France
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: Mexico
# Error converting country name: India
# Error converting country name: United States
# Error converting country name: France
# Error converting country name: United States
# Error converting country name: Spain
# Error converting country name: United States
# Error converting country name: China
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: United States
# Error converting country name: Canada
# ...

# %%
df["Continient"] = df["Country | Territory"].apply(get_continient)

# %%
df[["Continient", "Net Worth"]].groupby(["Continent"]).sum().sort_values(by="Net Worth", ascending=False)
