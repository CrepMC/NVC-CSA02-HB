# %%
import pandas as pd
df = pd.read_csv("hockey_players_data.csv")
df
# Out:
#     number                     name position  games_played  goals  assists  \
# 0       13      Mikyla Grant-Mentis        F             6    5.0        4
# 1       44         Lindsay Eastwood        D             6    4.0        5
# 2        2             Taylor Woods        F             6    4.0        4
# 3       19           Brooke Boquist        F             6    2.0        2
# 4       67               Emma Woods        F             6    NaN        4
# 5       21   Breanne Wilson-Bennett        F             6    2.0        4
# 6       27               Amy Curlew        F             6    NaN        2
# 7       27  Sarah-Eve Coutu-Godbout        F             6    2.0        4
# 8       18         Taytum Clairmont        F             6    1.0        3
# 9       18         Taytum Clairmont        F             6    1.0        3
# 10      27        Shiann Darkangelo        F             6    NaN        3
# ...

# %%
df.isnull().sum()
# Out:
# number           0
# name             0
# position         0
# games_played     0
# goals           10
# assists          0
# PIM              0
# birthdate        0
# age              0
# birthplace       2
# weight          11
# height           1
# dtype: int64

# %%
df.dropna()
# Out:
#     number              name position  games_played  goals  assists  PIM  \
# 2        2      Taylor Woods        F             6    4.0        4    4
# 8       18  Taytum Clairmont        F             6    1.0        3   21
# 9       18  Taytum Clairmont        F             6    1.0        3   21
# 13       4      Sarah Steele        D             6    1.0        4    4
# 14      23       Megan Quinn        D             6    1.0        0    0
#
#    birthdate  age       birthplace  weight  height
# 2    4/12/94   26  Thunder Bay,ONT   160.0    5.04
# 8   11/28/93   26    Royal Oak, MI   177.0    5.11
# 9   11/28/93   26    Royal Oak, MI   177.0    5.11
# 13   9/11/94   25  Belleville, ONT   145.0    5.06
# 14    3/9/95   22  Burlington, ONT   165.0    5.05

# %%
df.dropna(axis=1)

# %%
df.drop{["birthdate", "birthplace,]}
